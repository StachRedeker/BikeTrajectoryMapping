# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# Define the file paths
train_files = ['own/data/1.csv', 'own/data/2.csv', 'own/data/4.csv']
validation_test_file = 'own/data/5.csv'

# Function to load and preprocess data
def load_and_preprocess_data(train_files, validation_test_file):
    # Load the training data
    train_dfs = [pd.read_csv(file) for file in train_files]
    
    # Load the validation and test data
    validation_test_df = pd.read_csv(validation_test_file)
    
    # Convert 'date/time' columns to datetime
    for df in train_dfs:
        df['datetime'] = pd.to_datetime(df['date/time'], errors='coerce')
    validation_test_df['datetime'] = pd.to_datetime(validation_test_df['date/time'], errors='coerce')
    
    # Process each training dataframe
    processed_train_dfs = []
    for df, file in zip(train_dfs, train_files):
        if '1.csv' in file:
            # Remove the first 1 minute and the last 3 minutes from the first training data (1.csv)
            train_start_time = df['datetime'].min() + pd.Timedelta(minutes=1)
            train_end_time = df['datetime'].max() - pd.Timedelta(minutes=3)
        elif '2.csv' in file:
            # Remove the first 3 minutes and the last 2.5 minutes from the second training data (2.csv)
            train_start_time = df['datetime'].min() + pd.Timedelta(minutes=3)
            train_end_time = df['datetime'].max() - pd.Timedelta(minutes=2.5)
        else:
            # Remove the first and last 1.5 minutes from the other training data (4.csv)
            train_start_time = df['datetime'].min() + pd.Timedelta(minutes=1.5)
            train_end_time = df['datetime'].max() - pd.Timedelta(minutes=1.5)
        processed_df = df[(df['datetime'] >= train_start_time) & (df['datetime'] <= train_end_time)]
        processed_train_dfs.append(processed_df)
    
    # Concatenate all processed training dataframes
    train_df = pd.concat(processed_train_dfs, ignore_index=True)
    
    # Split validation_test_df into validation and test sets
    mid_index = len(validation_test_df) // 2
    val_df = validation_test_df.iloc[:mid_index]
    test_df = validation_test_df.iloc[mid_index:]
    
    return train_df, val_df, test_df

# Load datasets
train_df, val_df, test_df = load_and_preprocess_data(train_files, validation_test_file)

print('Loading complete')
train_df.head(), val_df.head(), test_df.head()
# Out:
# 2024-06-25 16:09:18.429395: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-25 16:09:19.253753: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-06-25 16:09:19.253840: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-06-25 16:09:19.253846: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Loading complete
# (                    date/time     gyro_x    gyro_y    gyro_z   accel_x  \
#  0  2024-06-05 14:09:12.810708  47.229008  1.580153  4.488550  0.464475
#  1  2024-06-05 14:09:12.818031  47.030534  0.419847  5.343511 -0.964863
#  2  2024-06-05 14:09:12.824984  47.328244 -4.145038  6.557252 -0.799663
#  3  2024-06-05 14:09:12.832316  48.068702 -3.725191  6.763359  1.841141
#  4  2024-06-05 14:09:12.839155  47.679389 -1.847328  6.595420  3.287239
#
#      accel_y    accel_z          x          y                   timestamp  \
#  0  0.493206   7.393295  25.891441  53.151175  2024-06-05 14:09:12.810708
#  1  0.105345   7.541735  25.891441  53.151175  2024-06-05 14:09:12.818031
#  2  0.849942   8.384494  25.891441  53.151175  2024-06-05 14:09:12.824984
#  3  0.289698  10.572795  25.891441  53.151175  2024-06-05 14:09:12.832316
#  4  0.694318  11.298238  25.891441  53.151175  2024-06-05 14:09:12.839155
#
#        x_cam     y_cam     z_cam                   datetime
#  0  0.184902 -0.982724 -0.008102 2024-06-05 14:09:12.810708
#  1  0.184902 -0.982724 -0.008102 2024-06-05 14:09:12.818031
#  2  0.184902 -0.982724 -0.008102 2024-06-05 14:09:12.824984
test_X_scaled = scaler.transform(test_df[features])

# Extract target values
train_y = train_df[targets].values
val_y = val_df[targets].values
test_y = test_df[targets].values

# Convert the data into sequences
def create_sequences(data, truth, sequence_length=800):
    sequences = []
    labels = []
    for i in range(len(data) - sequence_length):
        sequences.append(data[i:i+sequence_length])
        labels.append(truth[i+sequence_length])
    return np.array(sequences), np.array(labels)

sequence_length = 800
X_train, y_train = create_sequences(train_X_scaled, train_y, sequence_length)
X_val, y_val = create_sequences(val_X_scaled, val_y, sequence_length)
X_test, y_test = create_sequences(test_X_scaled, test_y, sequence_length)

print('Input sequences complete')
# Out:
# Input sequences complete

# %%
import os
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, BatchNormalization, MaxPooling1D, Dropout, LSTM, Dense
from tensorflow.keras.optimizers import Adam

# Define the model with fewer layers to reduce overfitting
model = Sequential([
    Conv1D(filters=8, kernel_size=3, activation='relu', input_shape=(sequence_length, len(features))),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    LSTM(12, return_sequences=True, kernel_regularizer='l2'),
    BatchNormalization(),
    LSTM(12, kernel_regularizer='l2'),
    Dropout(0.3),
    Dense(12, activation='relu', kernel_regularizer='l2'),
    Dense(len(targets))
])

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse', metrics=[RootMeanSquaredError(name='rmse')])
model.summary()

# Define the checkpoint
checkpoint_filepath = 'trajectory_model8-checkpoint.h5'
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Load weights if checkpoint exists
if os.path.exists(checkpoint_filepath):
    model.load_weights(checkpoint_filepath)
    print('Checkpoint loaded.')

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_val, y_val),
                    callbacks=[early_stopping, reduce_lr, checkpoint_callback])

# Evaluate the model
test_loss, test_rmse = model.evaluate(X_test, y_test)
print(f'Test RMSE: {test_rmse:.4f} meters')

# Export the model
model.save('trajectory_model8.h5')
# Out:
# 2024-06-16 00:09:16.690641: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: /usr/lib/x86_64-linux-gnu/libcuda.so.1: file too short; LD_LIBRARY_PATH: /usr/local/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-06-16 00:09:16.698085: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 798, 8)            224
#
#  batch_normalization (BatchN  (None, 798, 8)           32
#  ormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 399, 8)           0
#  )
#
#  dropout (Dropout)           (None, 399, 8)            0
#
#  lstm (LSTM)                 (None, 399, 12)           1008
#
#  batch_normalization_1 (Batc  (None, 399, 12)          48
#  hNormalization)
#
#  lstm_1 (LSTM)               (None, 12)                1200
#
#  dropout_1 (Dropout)         (None, 12)                0
#
#  dense (Dense)               (None, 12)                156
#
#  dense_1 (Dense)             (None, 2)                 26
#
# =================================================================
# Total params: 2,694
# Trainable params: 2,654
# Non-trainable params: 40
# _________________________________________________________________
# Checkpoint loaded.
# Epoch 1/50
# 5110/5110 [==============================] - ETA: 0s - loss: 54.4743 - rmse: 7.2743
# Epoch 1: loss improved from inf to 54.47433, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1092s 213ms/step - loss: 54.4743 - rmse: 7.2743 - val_loss: 197.6233 - val_rmse: 14.0014 - lr: 0.0010
# Epoch 2/50
# 5110/5110 [==============================] - ETA: 0s - loss: 51.6148 - rmse: 7.0718
# Epoch 2: loss improved from 54.47433 to 51.61483, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1100s 215ms/step - loss: 51.6148 - rmse: 7.0718 - val_loss: 199.8418 - val_rmse: 14.0792 - lr: 0.0010
# Epoch 3/50
# 5110/5110 [==============================] - ETA: 0s - loss: 50.5163 - rmse: 6.9920
# Epoch 3: loss improved from 51.61483 to 50.51630, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1092s 214ms/step - loss: 50.5163 - rmse: 6.9920 - val_loss: 231.6154 - val_rmse: 15.1649 - lr: 0.0010
# Epoch 4/50
# 5110/5110 [==============================] - ETA: 0s - loss: 47.2398 - rmse: 6.7523
# Epoch 4: loss improved from 50.51630 to 47.23984, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1112s 218ms/step - loss: 47.2398 - rmse: 6.7523 - val_loss: 203.4653 - val_rmse: 14.2060 - lr: 0.0010
# Epoch 5/50
# 5110/5110 [==============================] - ETA: 0s - loss: 46.1515 - rmse: 6.6704
# Epoch 5: loss improved from 47.23984 to 46.15148, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1108s 217ms/step - loss: 46.1515 - rmse: 6.6704 - val_loss: 227.9289 - val_rmse: 15.0421 - lr: 0.0010
# Epoch 6/50
# 5110/5110 [==============================] - ETA: 0s - loss: 45.4423 - rmse: 6.6158
# Epoch 6: loss improved from 46.15148 to 45.44233, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1114s 218ms/step - loss: 45.4423 - rmse: 6.6158 - val_loss: 197.8141 - val_rmse: 14.0046 - lr: 0.0010
# Epoch 7/50
# 5110/5110 [==============================] - ETA: 0s - loss: 40.0067 - rmse: 6.1901
# Epoch 7: loss improved from 45.44233 to 40.00667, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1227s 240ms/step - loss: 40.0067 - rmse: 6.1901 - val_loss: 210.1099 - val_rmse: 14.4368 - lr: 5.0000e-04
# Epoch 8/50
# 5110/5110 [==============================] - ETA: 0s - loss: 40.3030 - rmse: 6.2141
# Epoch 8: loss did not improve from 40.00667
# 5110/5110 [==============================] - 1053s 206ms/step - loss: 40.3030 - rmse: 6.2141 - val_loss: 202.8774 - val_rmse: 14.1842 - lr: 5.0000e-04
# Epoch 9/50
# 5110/5110 [==============================] - ETA: 0s - loss: 38.7826 - rmse: 6.0907
# Epoch 9: loss improved from 40.00667 to 38.78256, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1061s 208ms/step - loss: 38.7826 - rmse: 6.0907 - val_loss: 204.4389 - val_rmse: 14.2392 - lr: 5.0000e-04
# Epoch 10/50
# 5110/5110 [==============================] - ETA: 0s - loss: 37.9736 - rmse: 6.0240
# Epoch 10: loss improved from 38.78256 to 37.97359, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1426s 279ms/step - loss: 37.9736 - rmse: 6.0240 - val_loss: 196.1494 - val_rmse: 13.9450 - lr: 5.0000e-04
# Epoch 11/50
# 5110/5110 [==============================] - ETA: 0s - loss: 37.7771 - rmse: 6.0073
# Epoch 11: loss improved from 37.97359 to 37.77711, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1033s 202ms/step - loss: 37.7771 - rmse: 6.0073 - val_loss: 208.4533 - val_rmse: 14.3794 - lr: 5.0000e-04
# Epoch 12/50
# 5110/5110 [==============================] - ETA: 0s - loss: 37.0410 - rmse: 5.9456
# Epoch 12: loss improved from 37.77711 to 37.04100, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1033s 202ms/step - loss: 37.0410 - rmse: 5.9456 - val_loss: 226.8897 - val_rmse: 15.0067 - lr: 5.0000e-04
# Epoch 13/50
# 5110/5110 [==============================] - ETA: 0s - loss: 36.6764 - rmse: 5.9150
# Epoch 13: loss improved from 37.04100 to 36.67645, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1038s 203ms/step - loss: 36.6764 - rmse: 5.9150 - val_loss: 190.8381 - val_rmse: 13.7532 - lr: 5.0000e-04
# Epoch 14/50
# 5110/5110 [==============================] - ETA: 0s - loss: 35.6780 - rmse: 5.8301
# Epoch 14: loss improved from 36.67645 to 35.67803, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1119s 219ms/step - loss: 35.6780 - rmse: 5.8301 - val_loss: 192.8007 - val_rmse: 13.8245 - lr: 5.0000e-04
# Epoch 15/50
# 5110/5110 [==============================] - ETA: 0s - loss: 36.1218 - rmse: 5.8684
# Epoch 15: loss did not improve from 35.67803
# 5110/5110 [==============================] - 1009s 198ms/step - loss: 36.1218 - rmse: 5.8684 - val_loss: 211.6911 - val_rmse: 14.4917 - lr: 5.0000e-04
# Epoch 16/50
# 5110/5110 [==============================] - ETA: 0s - loss: 35.2484 - rmse: 5.7935
# Epoch 16: loss improved from 35.67803 to 35.24844, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1004s 196ms/step - loss: 35.2484 - rmse: 5.7935 - val_loss: 200.7973 - val_rmse: 14.1106 - lr: 5.0000e-04
# Epoch 17/50
# 5110/5110 [==============================] - ETA: 0s - loss: 34.7775 - rmse: 5.7527
# Epoch 17: loss improved from 35.24844 to 34.77747, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1271s 249ms/step - loss: 34.7775 - rmse: 5.7527 - val_loss: 211.8921 - val_rmse: 14.4986 - lr: 5.0000e-04
# Epoch 18/50
# 5110/5110 [==============================] - ETA: 0s - loss: 34.6381 - rmse: 5.7409
# Epoch 18: loss improved from 34.77747 to 34.63810, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 992s 194ms/step - loss: 34.6381 - rmse: 5.7409 - val_loss: 211.4499 - val_rmse: 14.4836 - lr: 5.0000e-04
# Epoch 19/50
# 5110/5110 [==============================] - ETA: 0s - loss: 32.7100 - rmse: 5.5707
# Epoch 19: loss improved from 34.63810 to 32.71002, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 997s 195ms/step - loss: 32.7100 - rmse: 5.5707 - val_loss: 197.5139 - val_rmse: 13.9942 - lr: 2.5000e-04
# Epoch 20/50
# 5110/5110 [==============================] - ETA: 0s - loss: 32.2664 - rmse: 5.5312
# Epoch 20: loss improved from 32.71002 to 32.26643, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 978s 191ms/step - loss: 32.2664 - rmse: 5.5312 - val_loss: 196.3930 - val_rmse: 13.9543 - lr: 2.5000e-04
# Epoch 21/50
# 5110/5110 [==============================] - ETA: 0s - loss: 31.8353 - rmse: 5.4924
# Epoch 21: loss improved from 32.26643 to 31.83528, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 977s 191ms/step - loss: 31.8353 - rmse: 5.4924 - val_loss: 201.5029 - val_rmse: 14.1365 - lr: 2.5000e-04
# Epoch 22/50
# 5110/5110 [==============================] - ETA: 0s - loss: 31.8078 - rmse: 5.4906
# Epoch 22: loss improved from 31.83528 to 31.80777, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 1254s 245ms/step - loss: 31.8078 - rmse: 5.4906 - val_loss: 202.3516 - val_rmse: 14.1666 - lr: 2.5000e-04
# Epoch 23/50
# 5110/5110 [==============================] - ETA: 0s - loss: 31.6329 - rmse: 5.4749
# Epoch 23: loss improved from 31.80777 to 31.63289, saving model to trajectory_model8-checkpoint.h5
# 5110/5110 [==============================] - 965s 189ms/step - loss: 31.6329 - rmse: 5.4749 - val_loss: 192.4994 - val_rmse: 13.8146 - lr: 2.5000e-04
# 3140/3140 [==============================] - 122s 39ms/step - loss: 208.6573 - rmse: 14.3865
# Test RMSE: 14.3865 meters

# %%
from tensorflow.keras.models import load_model

# Load the model and test it
loaded_model = load_model('trajectory_model8.h5')

# Predict using the test data
y_pred = loaded_model.predict(X_test)

# Create a DataFrame to store the true and predicted values
data = {
    'true_x': y_test[:, 0],
    'predicted_x': y_pred[:, 0],
    'true_y': y_test[:, 1],
    'predicted_y': y_pred[:, 1]
}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('trajectory_predictions8-7.csv', index=False)

# Plot the results
plt.figure(figsize=(15, 5))
plt.plot(y_test[:, 0], label='True X')
plt.plot(y_pred[:, 0], label='Predicted X')
plt.legend()
plt.title('X Trajectory')
plt.show()

plt.figure(figsize=(15, 5))
plt.plot(y_test[:, 1], label='True Y')
plt.plot(y_pred[:, 1], label='Predicted Y')
plt.legend()
plt.title('Y Trajectory')
plt.show()
# Out:
# 2108/2108 [==============================] - 85s 40ms/step

# %%
from sklearn.metrics import mean_squared_error
# Load the model and test it
loaded_model = load_model('trajectory_model8.h5')

# Predict using the test data
y_pred = loaded_model.predict(X_test)

# Calculate the RMSE
rmse_before_filter = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'RMSE before filtering: {rmse_before_filter}')

# Apply a moving average filter to the predicted data
def moving_average(data, window_size=100):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

# Apply moving average filter to each predicted dimension separately
y_pred_filtered = np.array([moving_average(y_pred[:, i]) for i in range(y_pred.shape[1])]).T

# Align the test data to match the length of the filtered predictions
y_test_aligned = y_test[len(y_test) - len(y_pred_filtered):]

# Calculate the RMSE again after filtering
rmse_after_filter = np.sqrt(mean_squared_error(y_test_aligned, y_pred_filtered))
print(f'RMSE after filtering: {rmse_after_filter}')

# Plot the results
plt.figure(figsize=(15, 5))
plt.plot(y_test[:, 0], label='True X')
#plt.plot(y_pred[:, 0], label='Predicted X')
plt.plot(np.arange(len(y_test) - len(y_pred_filtered), len(y_test)), y_pred_filtered[:, 0], label='Filtered Predicted X')
plt.legend()
plt.title('X Trajectory')
plt.show()

plt.figure(figsize=(15, 5))
plt.plot(y_test[:, 1], label='True Y')
#plt.plot(y_pred[:, 1], label='Predicted Y')
plt.plot(np.arange(len(y_test) - len(y_pred_filtered), len(y_test)), y_pred_filtered[:, 1], label='Filtered Predicted Y')
plt.legend()
plt.title('Y Trajectory')
plt.show()
# Out:
# 3140/3140 [==============================] - 123s 39ms/step
# RMSE before filtering: 14.386472468592444
# RMSE after filtering: 14.122701380345235

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# Define the file paths
train_files = ['own/data/1.csv', 'own/data/2.csv', 'own/data/4.csv']
validation_test_file = 'own/data/7.csv'

# Function to load and preprocess data
def load_and_preprocess_data(train_files, validation_test_file):
    # Load the training data
    train_dfs = [pd.read_csv(file) for file in train_files]
    
    # Load the validation and test data
    validation_test_df = pd.read_csv(validation_test_file)
    
    # Convert 'date/time' columns to datetime
    for df in train_dfs:
        df['datetime'] = pd.to_datetime(df['date/time'], errors='coerce')
    validation_test_df['datetime'] = pd.to_datetime(validation_test_df['date/time'], errors='coerce')
    
    # Process each training dataframe
    processed_train_dfs = []
    for df, file in zip(train_dfs, train_files):
        if '1.csv' in file:
            # Remove the first 1 minute and the last 3 minutes from the first training data (1.csv)
            train_start_time = df['datetime'].min() + pd.Timedelta(minutes=1)
            train_end_time = df['datetime'].max() - pd.Timedelta(minutes=3)
        elif '2.csv' in file:
            # Remove the first 3 minutes and the last 2.5 minutes from the second training data (2.csv)
            train_start_time = df['datetime'].min() + pd.Timedelta(minutes=3)
            train_end_time = df['datetime'].max() - pd.Timedelta(minutes=2.5)
        else:
            # Remove the first and last 1.5 minutes from the other training data (4.csv)
            train_start_time = df['datetime'].min() + pd.Timedelta(minutes=1.5)
            train_end_time = df['datetime'].max() - pd.Timedelta(minutes=1.5)
        processed_df = df[(df['datetime'] >= train_start_time) & (df['datetime'] <= train_end_time)]
        processed_train_dfs.append(processed_df)
    
    # Concatenate all processed training dataframes
    train_df = pd.concat(processed_train_dfs, ignore_index=True)
    
    # Split validation_test_df into validation and test sets
    mid_index = len(validation_test_df) // 2
    val_df = validation_test_df.iloc[:mid_index]
    test_df = validation_test_df
    
    return train_df, val_df, test_df

# Load datasets
train_df, val_df, test_df = load_and_preprocess_data(train_files, validation_test_file)

print('Loading complete')
train_df.head(), val_df.head(), test_df.head()
# Out:
# 2024-06-26 14:36:57.834820: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-26 14:36:58.785011: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-06-26 14:36:58.785130: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-06-26 14:36:58.785137: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Loading complete
# (                    date/time     gyro_x    gyro_y    gyro_z   accel_x  \
#  0  2024-06-05 14:09:12.810708  47.229008  1.580153  4.488550  0.464475
#  1  2024-06-05 14:09:12.818031  47.030534  0.419847  5.343511 -0.964863
#  2  2024-06-05 14:09:12.824984  47.328244 -4.145038  6.557252 -0.799663
#  3  2024-06-05 14:09:12.832316  48.068702 -3.725191  6.763359  1.841141
#  4  2024-06-05 14:09:12.839155  47.679389 -1.847328  6.595420  3.287239
#
#      accel_y    accel_z          x          y                   timestamp  \
#  0  0.493206   7.393295  25.891441  53.151175  2024-06-05 14:09:12.810708
#  1  0.105345   7.541735  25.891441  53.151175  2024-06-05 14:09:12.818031
#  2  0.849942   8.384494  25.891441  53.151175  2024-06-05 14:09:12.824984
#  3  0.289698  10.572795  25.891441  53.151175  2024-06-05 14:09:12.832316
